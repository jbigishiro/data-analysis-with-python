# %% [markdown]
# ## Hands-on lab: Exploratory Data Analysis - Laptops Pricing dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
filepath="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod2.csv"
df = pd.read_csv(filepath, header=0)

# %%
df=df.iloc[:, 3:]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Category          238 non-null    int64
#  1   GPU               238 non-null    int64
#  2   OS                238 non-null    int64
#  3   CPU_core          238 non-null    int64
#  4   Screen_Size_inch  238 non-null    float64
#  5   CPU_frequency     238 non-null    float64
#  6   RAM_GB            238 non-null    int64
#  7   Storage_GB_SSD    238 non-null    int64
#  8   Weight_pounds     238 non-null    float64
#  9   Price             238 non-null    int64
#  10  Price-binned      238 non-null    object
#  11  Screen-Full_HD    238 non-null    int64
#  12  Screen-IPS_panel  238 non-null    int64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 24.3+ KB

# %% [markdown]
# ### Task 1 - Visualize individual feature patterns

# %% [markdown]
# #### Continuous valued features

# %% [markdown]
# 1. CPU vs Price

# %%
# CPU_frequency plot
sns.regplot(x="CPU_frequency", y="Price", data=df)
# Out:
# <Axes: xlabel='CPU_frequency', ylabel='Price'>

# %%
# Correlation
df[['CPU_frequency', 'Price']].corr()
# Out:
#                CPU_frequency     Price
# CPU_frequency       1.000000  0.366666
# Price               0.366666  1.000000

# %% [markdown]
# 2. Screen Size vs Price

# %%
# Screen_size plot
sns.regplot(x="Screen_Size_inch", y="Price", data=df)
# Out:
# <Axes: xlabel='Screen_Size_inch', ylabel='Price'>

# %%
# Correlation
df[['Screen_Size_inch', 'Price']].corr()
# Out:
#                   Screen_Size_inch     Price
# Screen_Size_inch          1.000000 -0.110644
# Price                    -0.110644  1.000000

# %% [markdown]
# 3. Weight vs Price

# %%
# Weight_pounds plot
sns.regplot(x="Weight_pounds", y="Price", data=df)
# Out:
# <Axes: xlabel='Weight_pounds', ylabel='Price'>

# %%
# Correlation
df[['Weight_pounds', 'Price']].corr()
# Out:
#                Weight_pounds     Price
# Weight_pounds       1.000000 -0.050312
# Price              -0.050312  1.000000

# %%
df
# Out:
#      Category  GPU  OS  CPU_core  Screen_Size_inch  CPU_frequency  RAM_GB  \
# 0           4    2   1         5              14.0       0.551724       8
# 1           3    1   1         3              15.6       0.689655       4
# 2           3    1   1         7              15.6       0.931034       8
# 3           4    2   1         5              13.3       0.551724       8
# 4           4    2   1         7              15.6       0.620690       8
# ..        ...  ...  ..       ...               ...            ...     ...
# 233         4    2   1         7              14.0       0.896552       8
# 234         3    2   1         5              13.3       0.827586       8
# 235         4    2   1         5              12.0       0.896552       8
# 236         3    3   1         5              15.6       0.862069       6
# 237         3    2   1         5              14.0       0.793103       8
#
#      Storage_GB_SSD  Weight_pounds  Price Price-binned  Screen-Full_HD  \
# 0               256        3.52800    978          Low               0
# 1               256        4.85100    634          Low               1
# 2               256        4.85100    946          Low               1
# 3               128        2.69010   1244          Low               0
# 4               256        4.21155    837          Low               1
# ..              ...            ...    ...          ...             ...
# 233             256        3.74850   1891       Medium               0
# 234             256        2.64600   1950       Medium               1
# 235             256        2.99880   2236       Medium               0
# 236             256        5.29200    883          Low               1
# 237             256        4.29975   1499          Low               1
#
#      Screen-IPS_panel
# 0                   1
# 1                   0
# 2                   0
# 3                   1
# 4                   0
# ..                ...
# 233                 1
# 234                 0
# 235                 1
# 236                 0
# 237                 0
#
# [238 rows x 13 columns]

# %% [markdown]
# #### Categorical features

# %% [markdown]
# 1. Category vs Price

# %%
# Category Box plot
sns.boxplot(x="Category", y="Price", data=df)
# Out:
# <Axes: xlabel='Category', ylabel='Price'>

# %% [markdown]
# 2. GPU vs Price

# %%
# GPU Box plot
sns.boxplot(x="GPU", y="Price", data=df)
# Out:
# <Axes: xlabel='GPU', ylabel='Price'>

# %% [markdown]
# 3. OS vs Price

# %%
# OS Box plot
sns.boxplot(x="OS", y="Price", data=df)
# Out:
# <Axes: xlabel='OS', ylabel='Price'>

# %% [markdown]
# 4. CPU core VS Price

# %%
# CPU_core Box plot
sns.boxplot(x="CPU_core", y="Price", data=df)
# Out:
# <Axes: xlabel='CPU_core', ylabel='Price'>

# %% [markdown]
# 5. RAM_GB vs Price

# %%
# RAM Box plot
sns.boxplot(x="RAM_GB", y="Price", data=df)
# Out:
# <Axes: xlabel='RAM_GB', ylabel='Price'>

# %% [markdown]
# 6. Storage_GB_SSD vs Price

# %%
# Storage Box plot
sns.boxplot(x="Storage_GB_SSD", y="Price", data=df)
# Out:
# <Axes: xlabel='Storage_GB_SSD', ylabel='Price'>

# %% [markdown]
# ### Task 2 - Descriptive Statistical Analysis

# %%
df.describe(include="all")
# Out:
#           Category         GPU          OS    CPU_core  Screen_Size_inch  \
# count   238.000000  238.000000  238.000000  238.000000        238.000000
# unique         NaN         NaN         NaN         NaN               NaN
# top            NaN         NaN         NaN         NaN               NaN
# freq           NaN         NaN         NaN         NaN               NaN
# mean      3.205882    2.151261    1.058824    5.630252         14.688655
# std       0.776533    0.638282    0.235790    1.241787          1.166045
# min       1.000000    1.000000    1.000000    3.000000         12.000000
# 25%       3.000000    2.000000    1.000000    5.000000         14.000000
# 50%       3.000000    2.000000    1.000000    5.000000         15.000000
# 75%       4.000000    3.000000    1.000000    7.000000         15.600000
# max       5.000000    3.000000    2.000000    7.000000         17.300000
#
#         CPU_frequency      RAM_GB  Storage_GB_SSD  Weight_pounds        Price  \
# count      238.000000  238.000000      238.000000     238.000000   238.000000
# unique            NaN         NaN             NaN            NaN          NaN
# top               NaN         NaN             NaN            NaN          NaN
# freq              NaN         NaN             NaN            NaN          NaN
# mean         0.813822    7.882353      245.781513       4.106221  1462.344538
# std          0.141860    2.482603       34.765316       1.078442   574.607699
# min          0.413793    4.000000      128.000000       1.786050   527.000000
# 25%          0.689655    8.000000      256.000000       3.246863  1066.500000
# 50%          0.862069    8.000000      256.000000       4.106221  1333.000000
# 75%          0.931034    8.000000      256.000000       4.851000  1777.000000
# max          1.000000   16.000000      256.000000       7.938000  3810.000000
#
#        Price-binned  Screen-Full_HD  Screen-IPS_panel
# count           238      238.000000        238.000000
# unique            3             NaN               NaN
# top             Low             NaN               NaN
# freq            160             NaN               NaN
# mean            NaN        0.676471          0.323529
# std             NaN        0.468809          0.468809
# min             NaN        0.000000          0.000000
# 25%             NaN        0.000000          0.000000
# 50%             NaN        1.000000          0.000000
# 75%             NaN        1.000000          1.000000
# max             NaN        1.000000          1.000000

# %%
df.describe(include=['object'])
# Out:
#        Price-binned
# count           238
# unique            3
# top             Low
# freq            160

# %% [markdown]
# ### Task 3 - GroupBy and Pivot Tables

# %%
df1 = df[['GPU', 'CPU_core', 'Price']]

# %%
df1_grouped = df1.groupby(['GPU', 'CPU_core'], as_index=False).mean()
df1_grouped
# Out:
#    GPU  CPU_core        Price
# 0    1         3   769.250000
# 1    1         5   998.500000
# 2    1         7  1167.941176
# 3    2         3   785.076923
# 4    2         5  1462.197674
# 5    2         7  1744.621622
# 6    3         3   784.000000
# 7    3         5  1220.680000
# 8    3         7  1945.097561

# %%
grouped_pivot = df1_grouped.pivot(index='GPU',columns='CPU_core')
grouped_pivot
# Out:
#                Price
# CPU_core           3            5            7
# GPU
# 1         769.250000   998.500000  1167.941176
# 2         785.076923  1462.197674  1744.621622
# 3         784.000000  1220.680000  1945.097561

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

fig.colorbar(im)

# %% [markdown]
# ### Task 4 - Pearson Correlation and p-values

# %%
for param in ['RAM_GB','CPU_frequency','Storage_GB_SSD','Screen_Size_inch','Weight_pounds','CPU_core','OS','GPU','Category']:
    pearson_coef, p_value = stats.pearsonr(df[param], df['Price'])
    print(param)
    print("The Pearson Correlation Coefficient for ",param," is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# RAM_GB
# The Pearson Correlation Coefficient for  RAM_GB  is 0.5492972971857844  with a P-value of P = 3.681560628842868e-20
# CPU_frequency
# The Pearson Correlation Coefficient for  CPU_frequency  is 0.36666555892588604  with a P-value of P = 5.5024633507134225e-09
# Storage_GB_SSD
# The Pearson Correlation Coefficient for  Storage_GB_SSD  is 0.2434207552181029  with a P-value of P = 0.00014898923191724174
# Screen_Size_inch
# The Pearson Correlation Coefficient for  Screen_Size_inch  is -0.11064420817118266  with a P-value of P = 0.08853397846830766
# Weight_pounds
# The Pearson Correlation Coefficient for  Weight_pounds  is -0.05031225837751549  with a P-value of P = 0.43976938534338944
# CPU_core
# The Pearson Correlation Coefficient for  CPU_core  is 0.4593977773355115  with a P-value of P = 7.912950127009034e-14
# OS
# The Pearson Correlation Coefficient for  OS  is -0.22172980114827384  with a P-value of P = 0.0005696642559246749
# GPU
# The Pearson Correlation Coefficient for  GPU  is 0.2882981988881428  with a P-value of P = 6.166949698364282e-06
# Category
# The Pearson Correlation Coefficient for  Category  is 0.28624275581264125  with a P-value of P = 7.225696235806733e-06
